# %% [markdown]
# **Import libraries**

# %%
import pandas as pd

# %% [markdown]
# ## **Viviendas (test)**

# %%
viv_01 = pd.read_csv("Data\Viviendas\CNPV2018_1VIV_A2_05.CSV")
viv_02 = pd.read_csv("Data\Viviendas\CNPV2018_1VIV_A2_08.CSV")
viv_01.head(5)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\V'
# <>:2: SyntaxWarning: invalid escape sequence '\V'
# <>:1: SyntaxWarning: invalid escape sequence '\V'
# <>:2: SyntaxWarning: invalid escape sequence '\V'
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_8828\2436283688.py:1: SyntaxWarning: invalid escape sequence '\V'
#   viv_01 = pd.read_csv("Data\Viviendas\CNPV2018_1VIV_A2_05.CSV")
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_8828\2436283688.py:2: SyntaxWarning: invalid escape sequence '\V'
#   viv_02 = pd.read_csv("Data\Viviendas\CNPV2018_1VIV_A2_08.CSV")
#    TIPO_REG  U_DPTO  U_MPIO  UA_CLASE  U_EDIFICA  COD_ENCUESTAS  U_VIVIENDA  \
# 0         1       5       1         1          1           3646           5
# 1         1       5       1         1          1           3649           6
# 2         1       5       1         1          1           3658          38
# 3         1       5       1         1          1           3662          40
# ...

# %% [markdown]
# **Merge test**

# %%
viv_merge = pd.concat([viv_01, viv_02])
viv_merge
# Out:
#         TIPO_REG  U_DPTO  U_MPIO  UA_CLASE  U_EDIFICA  COD_ENCUESTAS  \
# 0              1       5       1         1          1           3646
# 1              1       5       1         1          1           3649
# 2              1       5       1         1          1           3658
# 3              1       5       1         1          1           3662
# 4              1       5       1         1          1           3666
# ...          ...     ...     ...       ...        ...            ...
# 681904         1       8     849         3          3           3856
# 681905         1       8     849         3          3          25656
# 681906         1       8     849         3          3        4846098
# 681907         1       8     849         3          4          25654
# 681908         1       8     849         3          4        4846088
#
#         U_VIVIENDA  UVA_ESTATER  UVA1_TIPOTER  UVA2_CODTER  ...  VB_ACU  \
# ...

# %%
v03 = "Data\Viviendas\CNPV2018_1VIV_A2_11.CSV"
viv_03 = pd.read_csv(v03)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\V'
# <>:1: SyntaxWarning: invalid escape sequence '\V'
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_8828\2489264297.py:1: SyntaxWarning: invalid escape sequence '\V'
#   v03 = "Data\Viviendas\CNPV2018_1VIV_A2_11.CSV"

# %%
viv_03
# Out:
#          TIPO_REG  U_DPTO  U_MPIO  UA_CLASE  U_EDIFICA  COD_ENCUESTAS  \
# 0               1      11       1         1          1          60428
# 1               1      11       1         1          1          60478
# 2               1      11       1         1          1          60515
# 3               1      11       1         1          1          60705
# 4               1      11       1         1          1          60706
# ...           ...     ...     ...       ...        ...            ...
# 2524422         1      11       1         3        340      902077201
# 2524423         1      11       1         3        341      902099863
# 2524424         1      11       1         3        342      902106667
# 2524425         1      11       1         3        343      902107045
# 2524426         1      11       1         3        344      902160076
#
#          U_VIVIENDA  UVA_ESTATER  UVA1_TIPOTER  UVA2_CODTER  ...  VB_ACU  \
# ...

# %% [markdown]
# ## **Viviendas concat**

# %% [markdown]
# **Concat loop**
